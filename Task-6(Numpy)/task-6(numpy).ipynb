# %% [markdown]
# **Arrays**

# %%
#Arrays
import numpy

def arrays(arr):
    # complete this function
    a = numpy.array(arr,float)
    res = a[::-1]
    return res
    # use numpy.array

arr = input().strip().split(' ')
result = arrays(arr)
print(result)

# %% [markdown]
# **Shape and Reshape**

# %%
#Shape and Reshape
import numpy

def arrays(arr):
    a = numpy.array(arr,int)
    a.shape = (3,3)
    return a

arr = input().strip().split(' ')
result = arrays(arr)
print(result)

# %% [markdown]
# **Transpose and Flatten**

# %%
#Transpose and Flatten
import numpy

n, m = map(int, input().split())

storage = numpy.array([input().strip().split() for _ in range(n)], int)
print (storage.transpose())
print (storage.flatten())

# %% [markdown]
# **Concatenate**

# %%
#Concatenate
import numpy
P, N, M = map(int,input().split())
A = numpy.array([input().split() for _ in range(P)],int)
B = numpy.array([input().split() for _ in range(N)],int)
print(numpy.concatenate((A, B), axis = 0))

# %% [markdown]
# **Zero's and One's**

# %%
#Zeros and Ones
import numpy

nums = tuple(map(int, input().split()))
print (numpy.zeros(nums, dtype = numpy.int))
print (numpy.ones(nums, dtype = numpy.int))

# %% [markdown]
# **Eye and Identity**

# %%
#Eye and Identity
import numpy

n,m = map(int,input().split())
numpy.set_printoptions(legacy='1.13')
print(numpy.eye(n,m))

# %% [markdown]
# **Array Mathematics**

# %%
#Array Mathematics
import numpy as np

n, m = map(int, input().split())

list1 = np.array([list(map(int, input().split())) for i in range(n)])
list2 = np.array([list(map(int, input().split())) for i in range(n)])

#print(list1 + list2)
#print(list1 - list2)
#print(list1 * list2)
#print(list1 // list2)
#print(list1 % list2)
#print(list1 ** list2)

print(np.add(list1,list2))
print(np.subtract(list1,list2))
print(np.multiply(list1,list2))
print(np.floor_divide(list1,list2))
print(np.mod(list1,list2))
print(np.power(list1,list2))

# %% [markdown]
# **Floor Ceil and Rint**

# %%
#Floor Ceil and Rint
import numpy as np

np.set_printoptions(sign=' ')

my_array = np.array(input().split(),float)

print(np.floor(my_array))
print(np.ceil(my_array))
print(np.rint(my_array))

# %% [markdown]
# **Sum and Product**

# %%
#Sum and Product
import numpy

n,m=map(int,input().split())

a=numpy.array([list(map(int,input().split())) for i in range(n)])

res =numpy.sum(a, axis=0)

print(numpy.prod(res, axis = None))

# %% [markdown]
# **Min and Max**

# %%
#Min and Max

import numpy

n,m=map(int,input().split())

a=numpy.array([list(map(int,input().split())) for i in range(n)])

res =numpy.min(a, axis=1)

print(numpy.max(res, axis = None))

# %% [markdown]
# **Mean, Variance and Standard Deviation**

# %%
#Mean , variance and standard deviation
import numpy

n,m = map(int,input().split())

a=numpy.array([list(map(int,input().split())) for i in range(n)])
print(numpy.mean(a,axis=1))
print(numpy.var(a,axis=0))
print(round(numpy.std(a,None),11))

# %% [markdown]
# **Dot and Cross Product**

# %%
#Dot and Cross
import numpy

import numpy

n=int(input())

a=numpy.array([input().split() for _ in range(n)], int)
b=numpy.array([input().split() for _ in range(n)], int)
print(numpy.dot(a,b))

# %% [markdown]
# **Inner and Outer**

# %%
#Inner Outer
import numpy

n=int(input())
a=numpy.array([input().split() for _ in range(n)], int)
b=numpy.array([input().split() for _ in range(n)], int)

print(numpy.inner(a,b)) #Print Inner.
print(numpy.outer(a,b)) #Print Outer.

# %% [markdown]
# **Polynomials**

# %%
#Polynomials
import numpy

lst = [float(n) for n in input().split()]

n = float(input())

print(numpy.polyval(lst,n))

# %% [markdown]
# **Linear Algebra**

# %%
#Linear Algebra
import numpy

n=int(input())
a=numpy.array([input().split() for _ in range(n)],float)
res = round(numpy.linalg.det(a),2)
print(res)
